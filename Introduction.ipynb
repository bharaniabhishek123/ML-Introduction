# %% [markdown]
# <a href="https://colab.research.google.com/github/bharaniabhishek123/ML-Introduction-/blob/main/git_pull.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install graphviz

# %%
import graphviz

# %%
w = graphviz.Digraph()
arr = ['Learning','Planning','Reasoning','Manipulation','Perception']
w.edges(('AI', arr[i]) for i in range(0, 5))
w.unflatten(stagger=3)

# %% [markdown]
# Goal of AI :

# %%
w = graphviz.Digraph()
arr = ['Supervised Learning','Unsupervised Learning','Reinforcement Learning']
w.edges(('Machine Learning', arr[i]) for i in range(0, 3))
w

# %% [markdown]
# Supervised Learning is splited into Classification and Regression.

# %%
w = graphviz.Digraph()
arr = ['NN','SVM','Decision Tree','Naive Bayes','HMM']
w.edges(('Machine Learning Algorithms', arr[i]) for i in range(0, 5))
w

# %% [markdown]
# Talk about linear model like logistic regression here :
#
# may be directly start with mathematical equation and build the story for logistic regression as binary classifier. but linear in nature.
#
# Let us start with the example of predicting crude oil prices based on oil production in us, opec countries and other parameters. with an assumption that oil prices for the purpose of this workshop are only dependent on these two inputs.

# %%
ps = graphviz.Digraph(name='Basic-NN', node_attr={'shape': 'plaintext'})

ps.node('US oil production')
ps.node('OPEC oil prodiction')
ps.node('Model', shape='box')
ps.edge('US oil production', 'Model')
ps.edge('OPEC oil prodiction', 'Model')
ps.edge('Model', 'Crude Oil Prices')
ps.graph_attr['rankdir'] = 'LR'
ps

# %% [markdown]
# We want to model the relationship using NN and create a function such that given these two inputs the model will output the price of crude oil. A NN consits of neurons that take one or more input, does some math and produce an output.
#
# $h_\theta (x) = w x+ b$
#
# $x \in (x_1, x_2) $

# %%
ps = graphviz.Digraph(name='One-Layer-NN', node_attr={'shape': 'plaintext'})

ps.node('x1')
ps.node('x2')
ps.node('h1 = \n (x1*w1 + x2*w2) + b ', shape='circle')
ps.node('h2', shape='circle')
ps.node('o1', shape='circle')
ps.edge('x1', 'h1')
ps.edge('x2', 'h1')
ps.edge('x2', 'h2')
ps.edge('x1', 'h2')
ps.edge('h1', 'o1')
ps.edge('h2', 'o1')
ps.graph_attr['rankdir'] = 'LR'
ps.graph_attr['size'] = '22.5'
ps

# %% [markdown]
# How do I introduce Neural Networks ?
#
# We are beginning to get an undertanding on neural networks. These are non-linear models that involves lot's of matrix multiplication and other element wise non-linear operations. Let's start by building a basic NN.

# %% [markdown]
# should i copy the stuff from lecture 2 ?
